# %%
import pandas as pd

# %%
df = pd.read_csv("main.csv")

# %%
df
# Out:
#        Id2                                     Geography  \
# 0    10180                                   Abilene, TX
# 1    10420                                     Akron, OH
# 2    10500                                    Albany, GA
# 3    10580                   Albany-Schenectady-Troy, NY
# 4    10740                               Albuquerque, NM
# 5    10780                                Alexandria, LA
# 6    10900             Allentown-Bethlehem-Easton, PA-NJ
# 7    11020                                   Altoona, PA
# 8    11100                                  Amarillo, TX
# 9    11180                                      Ames, IA
# 10   11260                                 Anchorage, AK
# 11   11460                                 Ann Arbor, MI
# 12   11500              Anniston-Oxford-Jacksonville, AL
# 13   11540                                  Appleton, WI
# 14   11700                                 Asheville, NC
# ...
